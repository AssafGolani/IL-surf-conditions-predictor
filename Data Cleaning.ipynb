# %%
import time
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.options.mode.chained_assignment = None
# %matplotlib inline

# %%
df = pd.read_csv('./info.csv')
df
# Out:
#        Unnamed: 0              date  hour  swell_rating primary_swell_height  \
# 0               0  2020-01-01 02:00  12am             1                   1m
# 1               1  2020-01-01 05:00   3am             0                   1m
# 2               2  2020-01-01 08:00   6am             1                 0.9m
# 3               3  2020-01-01 11:00   9am             1                 0.8m
# 4               4  2020-01-01 14:00  12pm             0                 0.8m
# ...           ...               ...   ...           ...                  ...
# 17538       17538  2021-12-31 09:00   9am             1                 1.1m
# 17539       17539  2021-12-31 12:00  12pm             1                   1m
# 17540       17540  2021-12-31 15:00   3pm             1                 0.9m
# 17541       17541  2021-12-31 18:00   6pm             1                 0.9m
# 17542       17542  2021-12-31 21:00   9pm             0                 0.8m
#
#       primary_swell_period
# 0                       8s
# 1                       7s
# 2                       7s
# 3                       7s
# 4                       7s
# ...                    ...
# 17538                   7s
# 17539                   8s
# 17540                   8s
# 17541                   8s
# 17542                   8s
#
# [17543 rows x 6 columns]

# %%
del df["Unnamed: 0"]
df
# Out:
#                    date  hour  swell_rating primary_swell_height  \
# 0      2020-01-01 02:00  12am             1                   1m
# 1      2020-01-01 05:00   3am             0                   1m
# 2      2020-01-01 08:00   6am             1                 0.9m
# 3      2020-01-01 11:00   9am             1                 0.8m
# 4      2020-01-01 14:00  12pm             0                 0.8m
# ...                 ...   ...           ...                  ...
# 17538  2021-12-31 09:00   9am             1                 1.1m
# 17539  2021-12-31 12:00  12pm             1                   1m
# 17540  2021-12-31 15:00   3pm             1                 0.9m
# 17541  2021-12-31 18:00   6pm             1                 0.9m
# 17542  2021-12-31 21:00   9pm             0                 0.8m
#
#       primary_swell_period
# 0                       8s
# 1                       7s
# 2                       7s
# 3                       7s
# 4                       7s
# ...                    ...
# 17538                   7s
# 17539                   8s
# 17540                   8s
# 17541                   8s
# 17542                   8s
#
# [17543 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df.date, format='%Y-%m-%d %H:%M')
df
# Out:
#                      date  hour  swell_rating primary_swell_height  \
# 0     2020-01-01 02:00:00  12am             1                   1m
# 1     2020-01-01 05:00:00   3am             0                   1m
# 2     2020-01-01 08:00:00   6am             1                 0.9m
# 3     2020-01-01 11:00:00   9am             1                 0.8m
# 4     2020-01-01 14:00:00  12pm             0                 0.8m
# ...                   ...   ...           ...                  ...
# 17538 2021-12-31 09:00:00   9am             1                 1.1m
# 17539 2021-12-31 12:00:00  12pm             1                   1m
# 17540 2021-12-31 15:00:00   3pm             1                 0.9m
# 17541 2021-12-31 18:00:00   6pm             1                 0.9m
# 17542 2021-12-31 21:00:00   9pm             0                 0.8m
#
#       primary_swell_period
# 0                       8s
# 1                       7s
# 2                       7s
# 3                       7s
# 4                       7s
# ...                    ...
# 17538                   7s
# 17539                   8s
# 17540                   8s
# 17541                   8s
# 17542                   8s
#
# [17543 rows x 5 columns]

# %%
df['year'],df['month'],df['day'] = df.date.dt.year, df.date.dt.month, df.date.dt.day
del df["date"]

# %%
replace_12am = {'12am':'00:00'}
replace_3am = {'3am':'03:00'}
replace_6am = {'6am':'06:00'}
replace_9am = {'9am':'09:00'}
replace_12pm = {'12pm':'12:00'}
replace_3pm = {'3pm':'15:00'}
replace_6pm = {'6pm':'18:00'}
replace_9pm = {'9pm':'21:00'}
df=df.replace(replace_12am)
df=df.replace(replace_3am)
df=df.replace(replace_6am)
df=df.replace(replace_9am)
df=df.replace(replace_12pm)
df=df.replace(replace_3pm)
df=df.replace(replace_6pm)
df=df.replace(replace_9pm)
df
# Out:
#         hour  swell_rating primary_swell_height primary_swell_period  year  \
# 0      00:00             1                   1m                   8s  2020
# 1      03:00             0                   1m                   7s  2020
# 2      06:00             1                 0.9m                   7s  2020
# 3      09:00             1                 0.8m                   7s  2020
# 4      12:00             0                 0.8m                   7s  2020
# ...      ...           ...                  ...                  ...   ...
# 17538  09:00             1                 1.1m                   7s  2021
# 17539  12:00             1                   1m                   8s  2021
# 17540  15:00             1                 0.9m                   8s  2021
# 17541  18:00             1                 0.9m                   8s  2021
# 17542  21:00             0                 0.8m                   8s  2021
#
#        month  day
# 0          1    1
# 1          1    1
# 2          1    1
# 3          1    1
# 4          1    1
# ...      ...  ...
# 17538     12   31
# 17539     12   31
# 17540     12   31
# 17541     12   31
# 17542     12   31
#
# [17543 rows x 7 columns]

# %%
df["primary_swell_height"] = df['primary_swell_height'].str.rstrip("m")
df["primary_swell_period"] = df['primary_swell_period'].str.rstrip("s")
df
# Out:
#         hour  swell_rating primary_swell_height primary_swell_period  year  \
# 0      00:00             1                    1                    8  2020
# 1      03:00             0                    1                    7  2020
# 2      06:00             1                  0.9                    7  2020
# 3      09:00             1                  0.8                    7  2020
# 4      12:00             0                  0.8                    7  2020
# ...      ...           ...                  ...                  ...   ...
# 17538  09:00             1                  1.1                    7  2021
# 17539  12:00             1                    1                    8  2021
# 17540  15:00             1                  0.9                    8  2021
# 17541  18:00             1                  0.9                    8  2021
# 17542  21:00             0                  0.8                    8  2021
#
#        month  day
# 0          1    1
# 1          1    1
# 2          1    1
# 3          1    1
# 4          1    1
# ...      ...  ...
# 17538     12   31
# 17539     12   31
# 17540     12   31
# 17541     12   31
# 17542     12   31
#
# [17543 rows x 7 columns]

# %%
df = df.drop_duplicates()
df = df.dropna()
df
# Out:
#         hour  swell_rating primary_swell_height primary_swell_period  year  \
# 0      00:00             1                    1                    8  2020
# 1      03:00             0                    1                    7  2020
# 2      06:00             1                  0.9                    7  2020
# 3      09:00             1                  0.8                    7  2020
# 4      12:00             0                  0.8                    7  2020
# ...      ...           ...                  ...                  ...   ...
# 17532  15:00             1                  0.7                    8  2021
# 17534  21:00             0                  0.9                    7  2021
# 17538  09:00             1                  1.1                    7  2021
# 17540  15:00             1                  0.9                    8  2021
# 17541  18:00             1                  0.9                    8  2021
#
#        month  day
# 0          1    1
# 1          1    1
# 2          1    1
# 3          1    1
# 4          1    1
# ...      ...  ...
# 17532     12   30
# 17534     12   30
# 17538     12   31
# 17540     12   31
# 17541     12   31
#
# [9587 rows x 7 columns]

# %%
for col in df.columns:
    if col == 'primary_swell_height':
        df[col] = df[col].astype(float)
    if col == 'primary_swell_period':
        df[col] = df[col].astype(int)
    if col == 'swell_rating':
        df[col] = df[col].astype(int)

# %%
df.describe(include='all')
# Out:
#          hour  swell_rating  primary_swell_height  primary_swell_period  \
# count    9587   9587.000000           9587.000000           9587.000000
# unique      8           NaN                   NaN                   NaN
# top     21:00           NaN                   NaN                   NaN
# freq     1259           NaN                   NaN                   NaN
# mean      NaN      0.232815              0.812580              6.535621
# std       NaN      0.480189              0.608194              1.581389
# min       NaN      0.000000              0.100000              2.000000
# 25%       NaN      0.000000              0.400000              6.000000
# 50%       NaN      0.000000              0.700000              7.000000
# 75%       NaN      0.000000              1.000000              7.000000
# max       NaN      5.000000              5.100000             14.000000
#
#                year        month          day
# count   9587.000000  9587.000000  9587.000000
# unique          NaN          NaN          NaN
# top             NaN          NaN          NaN
# freq            NaN          NaN          NaN
# mean    2020.449359     6.236362    15.668405
# std        0.497455     3.534433     8.717552
# min     2020.000000     1.000000     1.000000
# 25%     2020.000000     3.000000     8.000000
# 50%     2020.000000     6.000000    16.000000
# 75%     2021.000000     9.000000    23.000000
# max     2021.000000    12.000000    31.000000

# %%
def outliers(df,col_name):
    sns.boxplot(x = df[col_name])
    Q1 = np.percentile(df[col_name], 25)
    Q3 = np.percentile(df[col_name], 75)
    IQR = Q3-Q1
    if col_name == 'primary_swell_period':
        IQR_range = 7
        df[col_name][(df[col_name] < Q1 - 1.5*IQR ) | (df[col_name] > Q3 + IQR_range*IQR)] = np.nan
        
    if col_name == 'primary_swell_height':
        IQR_range = 4
        df[col_name][(df[col_name] < Q1 - 1.5*IQR ) | (df[col_name] > Q3 + IQR_range*IQR)] = np.nan
        
    df = df[df[col_name].notna()]
    
    return df

# %%
df = outliers(df, 'primary_swell_height')

# %%
df = outliers(df, 'primary_swell_period')

# %%
df
# Out:
#         hour  swell_rating  primary_swell_height  primary_swell_period  year  \
# 0      00:00             1                   1.0                     8  2020
# 1      03:00             0                   1.0                     7  2020
# 2      06:00             1                   0.9                     7  2020
# 3      09:00             1                   0.8                     7  2020
# 4      12:00             0                   0.8                     7  2020
# ...      ...           ...                   ...                   ...   ...
# 17532  15:00             1                   0.7                     8  2021
# 17534  21:00             0                   0.9                     7  2021
# 17538  09:00             1                   1.1                     7  2021
# 17540  15:00             1                   0.9                     8  2021
# 17541  18:00             1                   0.9                     8  2021
#
#        month  day
# 0          1    1
# 1          1    1
# 2          1    1
# 3          1    1
# 4          1    1
# ...      ...  ...
# 17532     12   30
# 17534     12   30
# 17538     12   31
# 17540     12   31
# 17541     12   31
#
# [9546 rows x 7 columns]

# %%
df.to_csv('clean_info.csv')
